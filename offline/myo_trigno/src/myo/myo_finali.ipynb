# %%
import pandas as pd

# %%
df=pd.read_csv(r'C:\Users\nicol\Thesis\DATA real time\_testnew\S01\test1b\4\raw_emg_imu.csv')

# Selezionare le colonne da 'ACC_X' a 'GYR_Z'
colonne_selezionate = df.loc[:, 'ACC_X':'GYR_Z']

# Identificare e rimuovere le righe duplicate
df_senza_duplicati = colonne_selezionate.drop_duplicates()

# Visualizzare il DataFrame risultante
print(df_senza_duplicati)
# Out:
#           ACC_X     ACC_Y     ACC_Z     GYR_X     GYR_Y     GYR_Z
# 0      0.839844 -0.021484  0.481445 -3.231707 -0.365854 -2.012195
# 1      0.838867 -0.021973  0.473633 -2.073171 -1.219512 -2.012195
# 2      0.841309 -0.038086  0.475586 -0.609756 -1.707317 -1.219512
# 3      0.837891 -0.056152  0.486328 -3.231707 -1.524390 -1.524390
# 4      0.838867 -0.028809  0.471680 -5.243903 -1.890244 -1.951220
# ...         ...       ...       ...       ...       ...       ...
# 27425  0.806641 -0.134277  0.474121  0.609756  4.512195  1.036585
# 27426  0.816406 -0.138672  0.486328 -0.365854  5.121951  0.487805
# 27427  0.831055 -0.110840  0.495605  2.500000  7.195122  0.853659
# 27435  0.807129 -0.160156  0.445312 -0.548781  0.060976  1.341463
# 27436  0.791016 -0.135742  0.459961  1.890244  3.902439  2.073171
#
# [9450 rows x 6 columns]
